# %%
# %%time

import sys
import os

sys.path.append(os.path.abspath(".."))

from src.data_loader import load_data
from src.preprocess import preprocess_data
from src.train import train_models
from src.evaluate import evaluate_model
# Out:
# CPU times: total: 0 ns
# Wall time: 1.01 ms

# %%
df = load_data()
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
X_train, X_test, y_train, y_test, preprocessor = preprocess_data(df)

models = train_models(X_train, y_train, preprocessor)
# Out:
# LINEAR model saved at c:\Users\tejom\OneDrive\Desktop\Github\real-estate-price-prediction-ml\models\linear.joblib
# RIDGE model saved at c:\Users\tejom\OneDrive\Desktop\Github\real-estate-price-prediction-ml\models\ridge.joblib
# LASSO model saved at c:\Users\tejom\OneDrive\Desktop\Github\real-estate-price-prediction-ml\models\lasso.joblib

# %%
for name, model in models.items():
    r2, rmse = evaluate_model(model, X_test, y_test)
    print(f"{name.upper()} -> R2: {r2:.4f}, RMSE: {rmse:.4f}")
# Out:
# LINEAR -> R2: 0.5758, RMSE: 0.7456
# RIDGE -> R2: 0.5758, RMSE: 0.7456
# LASSO -> R2: 0.4814, RMSE: 0.8244
